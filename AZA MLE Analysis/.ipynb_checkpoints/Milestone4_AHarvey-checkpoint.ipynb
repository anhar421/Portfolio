# %% [markdown]
# ## Milestone 4

# %% [markdown]
# *Connecting to an API/Pulling in the Data and Cleaning/Formatting*
#
# Perform at least 5 data transformation and/or cleansing steps to your API data

# %% [markdown]
# I had to change my API source. The original API didn't have a good structure for just data scraping. I am using the API for the Global Biodiversity Information Facility now which is one of the organizations that my original API institution sends their data to.

# %%
import urllib.request, urllib.parse, urllib.error
import json
import pandas as pd
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
# Variables for the pieces of the API url to search for species
site = 'https://api.gbif.org/v1/'
species = 'occurrence/'
search = 'search?q='

# %%
# Import the list of AZA animals to search for
aza = pd.read_csv('dsc540_animalinfo.csv')

# %%
# I noticed there were some shorthand renditions of animals with multiple scientific names, so I manually changed them to the 
# most common scientific name in order for them to work with the API correctly.
aza = aza.replace(('Lithobates (Rana) sevosa', 'Enhydra lutris kenyoni & E. l. nereis', 'Ailurus fulgens refulgens (styani)', 'Bufo (Anaxyrus) houstonensis'), 
                  ('Lithobates sevosa', 'Enhydra lutris kenyoni', 'Ailurus fulgens refulgens', 'Anaxyrus houstonensis'))

# %%
# I turned the column of scientific names into a list for reformatting.
aza_names = aza['scientific_name'].tolist()

# %%
# Function to split the scientific names into genus, species, and (if applicable) subspecies. Need to split them in order to
# correctly format them for insertion into API call.
def split_name(name):
    split = []
    split.append(name.split())
    return split

# %%
# Function to format the split scientfic name into URL appropriate string for API call.
def format_name(names):
    formatted = [['%20'.join(n) for n in name] for name in names]
    return formatted

# %%
# Function to send list of names to be formatted into correct form for the API url. It uses the split_name and format_name 
# functions to first split each name, format each name, and return them to a list. The result is a list of lists
def api_names(list):
    names = []

    for name in list:
        names.append(split_name(name))
    
    api_list = format_name(names)
    return api_list

# %%
master = api_names(aza_names)
# Flatten list of lists for easier access.
flat_master = [item for sublist in master for item in sublist]

# %%
# I want to save the information from the API for each animal to a list. I only want specific tags in the API so I've isolated
# those and will select that information from the API.
def gather_intel(file):
    intel = []
    tmp = {}
    file_keys = ['year', 'month', 'day', 'country', 'locality', 'species', 'basisofRecord', 'occurrenceStatus', 'occurrenceRemarks']
   
    for item in file:
        for key, val in item.items():
            if key in file_keys:
                tmp.update({key: val})
        intel.append(tmp)
        tmp = {}
    return intel

# %%
# Access API
def find_species(animals):
    gbif_data = []
    for animal in animals:
        try:
            print('Accessing API...')
            print(site+species+search+animal)
            uh = urllib.request.urlopen(site+species+search+animal)
            data = uh.read()
            file = json.loads(data)
            results = file['results'] # Have to further slice the data because the original data has multiple dicts
            
            gbif_data.append(gather_intel(results))
        
        except urllib.error.URLError as e:
            print(f"ERROR: {e.reason}")
    return gbif_data

# %%
# Run all species through the API and collect the information using the find_species function.
new = find_species(flat_master)
# Out:
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Orycteropus%20afer
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Addax%20nasomaculatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Dasyprocta%20leporina
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Alligator%20sinensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Bubalus%20depressicornis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Myrmecophaga%20tridactyla
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Hippotragus%20equinus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Hippotragus%20niger
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pteroglossus%20viridis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Argusianus%20argus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tolypeutes%20matacas
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Papio%20hamadryas
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Rucervus%20duvaucelii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pogonornis%20dubius
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Trachyphonus%20erythrocephalus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pteropus%20rodricensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eidolon%20helvum
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tremarctos%20ornatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ursus%20thibetanus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ursus%20arctos
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ursus%20maritimus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Melursus%20ursinus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Helarctos%20malayanus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Castor%20canadensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Bettongia%20penicillata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Arctictis%20binturong
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Paradisaea%20raggiana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Irena%20puella
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Chilabothrus%20subflavus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lynx%20rufus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tragelaphus%20eurycerus%20isaaci
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pan%20paniscus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Damaliscus%20pygargus%20pygarus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Syncerus%20caffer
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Spizixos%20semitorques
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Galago%20moholi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lachesis%20muta
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lophotis%20gindiana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Turnix%20nigricollis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cacicus%20cela
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Callimico%20goeldii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Camelus%20bactrianus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Hydrochaeris%20hydrochaeris
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Caracal%20caracal
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Paroaria%20gularis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Paroaria%20coronata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Casuarius%20casuarius
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Felis%20nigripes
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Prionailurus%20viverrinus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Felis%20manul
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Felis%20margarita
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cossypha%20niveicapilla
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Acinonyx%20jubatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tragulus%20napu
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tympanuchus%20cupido%20attwateri
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pan%20troglodytes
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Sauromalus%20varius
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nasua%20narica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Colobus%20angolensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Colobus%20guereza
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Guarouba%20guarouba
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Zapornia%20flavirostra
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Balearica%20pavonina
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Anthropoides%20paradisea
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Anthropoides%20virgo
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Balearica%20regulorum
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Grus%20monacha
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Grus%20japonensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Bugeranus%20carunculatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Grus%20vipio
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Grus%20americana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pauxi%20pauxi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Crax%20globulosa
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Rucervus%20eldii%20thamin
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Mazama%20temama
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Elaphurus%20davidianus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Elaphodus%20cehalophus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Przewalskium%20albirostris
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Madoqua%20kirkii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Burhinus%20capensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lycaon%20pictus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Speothos%20venaticus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ptilinopus%20pulchellus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ptilinopus%20melanospilus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Chalcophaps%20indica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ptilinopus%20jambu
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Gallicolumba%20luzonica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ptilinopus%20roseicapilla
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Gallicolumba%20criniger
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ptilinopus%20porphyrea
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Varanus%20komodoensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Dendrocygna%20guttata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Dendrocygna%20arborea
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Asarcornis%20scutulata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cephalopus%20niger
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Philantomba%20monticola
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cephalophus%20silvicultor
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Haliaeetus%20leucoephalus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Taurotragus%20oryx
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Loxodonta%20africana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Elephas%20maximus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Polihierax%20semitorquatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phoenicopterus%20ruber
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phoenicopterus%20chilensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phoenicopterus%20ruber%20roseus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phoeniconaias%20minor
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pteropus%20hypomelanus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pteropus%20vampyrus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Vulpes%20zerda
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Vulpes%20velox
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lithobates%20sevosa
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Atelopus%20varius
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Atelopus%20zeteki
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Atelopus%20zeteki
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Podargus%20strigoides
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Otolemur%20garnettii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Celestus%20warreni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nanger%20granti
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nanger%20soemmerringii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Gazella%20leptoceros
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eudorcas%20thomsonii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Uroplatus%20fimbriatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Uroplatus%20henkeli
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Uroplatus%20lineatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Uroplatus%20sikorae
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Uroplatus%20phantasticus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Oryx%20gazella%20gazella
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Litocranius%20walleri
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Hylobates%20lar
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Giraffa%20camelopardalis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nettapus%20auritus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nettapus%20coromandelianus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Branta%20sandvicensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Branta%20ruficollis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Anser%20cygnoides
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Naemorhedus%20griseus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Gorilla%20gorilla%20gorilla
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Guttera%20pucherani
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Acryllium%20vulturinum
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Scopus%20umbretta
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cochlearius%20cochlearius
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cheoropis%20liberiensi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Hippopotamus%20amphibius
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Potamochoerus%20porcus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Bucorvus%20abyssinicus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Buceros%20bicornis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tockus%20erythrorhynchus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Buceros%20rhinoceros
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Rhabdotorrhinus%20corrugatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Equus%20ferus%20przewalskii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Crocuta%20crocuta
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Procavia%20capensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Capra%20nubiana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Plegadis%20ridgwayi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Threskiornis%20aethiopicus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eudocimus%20ruber
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Geronticus%20eremita
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Brachylophus%20bulabula
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pantera%20onca
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cyanocorax%20chrysops
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macropus%20rufus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nestor%20notabilis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Todiramphus%20cinnamominus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Potos%20flavus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Apteryx%20australis%20mantelli
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Oreotragus%20oreotragus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phascolarctos%20cinereus%20adustus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Kobus%20kob%20thomasi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Dacelo%20novaeguineae
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tragelaphus%20strepsiceros
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Trachypithecus%20francoisi%20francoisi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Trachypithecus%20cristatus%20ultimus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Vanellus%20miles
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Vanellus%20spinosus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Garrulax%20leucolophus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Kobus%20megaceros
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Kobus%20leche
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Leiothrix%20lutea
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Varecia%20variegata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eulemur%20collaris
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eulemur%20coronatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eulemur%20mongoz
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Microcebus%20murinus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Varecia%20rubra
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lemur%20catta
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Panthera%20pardus%20orientalis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Neofelis%20nebulosa
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Unica%20unica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Panthera%20leo
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Shinisaurus%20crocodilurus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Heloderma%20horridum%20exasperatum
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phrynosoma%20cornutum
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nycticebus%20pygmaeus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lynx%20canadensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macaca%20fuscata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macaca%20silenus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macaca%20nigra
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Anodorhynchus%20hyacinthinus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cyanopica%20cyanus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Urocissa%20erythrorhyncha
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Mandrillus%20sphinx
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cercocebus%20torquatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Capra%20falconeri%20heptneri
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Callithrix%20geoffroyi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Callithrix%20pygmaea
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Suricata%20suricatta
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Mergus%20squamatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Callicebus%20donacophilus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ateles%20goeffroyi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Saimiri%20sciureus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cercopithecus%20neglectus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cercopithecus%20diana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Erythrocebus%20patas
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ateles%20fusciceps%20robustus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cercopithecus%20ascanius%20schmidti
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Alouatta%20caraya
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Alces%20alces
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Momotus%20momota
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Peromyscus%20polionotus%20trissylepsis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Uria%20aalge
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Leucopsar%20rothschildi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ampeliceps%20coronatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tragelaphus%20angasii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Leopardus%20pardalis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Okapia%20johnstoni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pongo%20pygmaeus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pongo%20abelii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Psarocolius%20decumanus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Oryx%20leucoryx
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Oryx%20gazelle%20callotis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Oryx%20dammah
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Struthio%20camelus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Amblonyx%20cinereus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Lontra%20canadensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Enhydra%20lutris%20kenyoni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Athene%20cunicularia
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Nyctea%20scandiaca
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ailurus%20fulgens%20fulgens
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ailurus%20fulgens%20refulgens
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Deroptyus%20accipitrinus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Rhynchopsitta%20pachyrhyncha
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Rollulus%20rouloul
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Afropavo%20congensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pelicanus%20onocrotalus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pelecanus%20rufescens
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pygoscelis%20adeliae
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Speniscus%20demersus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pygoscelis%20antarctica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pygoscelis%20papua%20ellsworthi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pygoscelis%20papua%20papua
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Spheniscus%20humboldti
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Aptenodytes%20patagonicus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eudyptes%20chrysolophus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Spheniscus%20magellanicus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eudyptes%20chrysocome
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Polyplectron%20napoleonis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Otidiphaps%20nobilis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Caloenas%20nicobarica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Goura%20victoria
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Goura%20cristata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pitta%20sordida
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Hystrix%20africaeaustralis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Erethizon%20dorsatum
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Coendou%20prehensilis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pudu%20puda
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Fratercula%20arctica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Fratercula%20cirrhata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Puma%20concolor
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Python%20reticulatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Dasyurus%20maculatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Gallirallus%20owstoni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Sistrurus%20catenatus%20catenatus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Crotalus%20polystictus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Rhea%20americana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Diceros%20bicornis%20michaeli
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Rhinoceros%20unicornis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cerathotherium%20simum
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Bassariscus%20astutus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Coracias%20cyanogaster
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pithecia%20pithecia
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Chauna%20torquata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Zalophus%20californianus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Halichoerus%20grypus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phoca%20vitulina
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cariama%20cristata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Leptailurus%20serval
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Carcharias%20taurus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ovis%20canadensis%20nelsoni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Symphalangus%20syndactylus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Propithecus%20coquereli
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tragelaphus%20spekii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Corucia%20zebrata
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Choleopus%20hoffmanni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Choleopus%20didactylus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Drymarchon%20couperi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Pituophis%20ruthveni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Poecilotheria%20metallica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ajaia%20ajaja
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Antidorcas%20marsupialis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Callosciurus%20prevostii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Coccycolius%20iris
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cosmopsarus%20regius
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Scissirostrum%20dubium
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cinnyricinclus%20leucogaster
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Raphicerus%20campestris
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Himantopus%20mexicanus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Potamotrygon%20motoro
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Potamotrygon%20leopoldi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ciconia%20ciconia%20ciconia
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Leptoptilos%20crumenifer
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Mycteria%20leucocephala
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ephippiorhynchus%20senegalensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Mycteria%20ibis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eurypyga%20helias
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Coscoroba%20coscoroba
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Cygnus%20buccinator
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Budorcas%20taxicolor%20tibetana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tamandua%20tetradactyla
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Saguinus%20imperator%20subgrisescens
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Saguinus%20oedipus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Leontopithecus%20chrysomelas
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Sanguinus%20bicolor
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Thraupis%20episcopus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ramphocelus%20carbo
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tangara%20mexicana
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tapirus%20indicus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Brachypelma%20smithi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Marmaronetta%20angustirostris
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Echinops%20telfairi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Larosterna%20inca
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Batagur%20borneoensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Copsychus%20malabaricus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Panthera%20tigris%20altaica
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Panthera%20tigris%20jacksoni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Panthera%20tigris%20sumatrae
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Eudromia%20elegans
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Anaxyrus%20houstonensis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Peltophryne%20lemur
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Anaxyrus%20baxteri
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Testudo%20kleinmanni
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ramphastos%20ambiguus%20swainsonii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ramphastos%20sulfuratus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Ramphastos%20toco
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tragopan%20caboti
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Dendrolagus%20matschiei
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tupaia%20belangeri
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Icterus%20icterus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Psophia%20crepitans
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Musophaga%20rossae
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tauraco%20erythrolophus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Musophaga%20violacea
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Tauraco%20leucotis
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Terrapene%20coahuila
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Glyptemys%20insculpta
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Parias%20flavomaculatus%20mcgregori
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Aeypius%20monachus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Sarcorhamphus%20papa
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macropus%20rufogriseus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macropus%20parma
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macropus%20eugenii
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Petrogale%20xanthopus%20xanthopus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Macropus%20robustus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phacochoerus%20africanus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Dinemellia%20dinemelli
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Connochaetes%20taurinus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Chrysocyon%20brachyurus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Canis%20lupus%20baileyi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Canis%20rufus%20gregoryi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Phoeniculus%20purpureus
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Equus%20grevyi
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Equus%20zebra%20hartmannae
# Accessing API...
# https://api.gbif.org/v1/occurrence/search?q=Equus%20quagga

# %%
# Turn data into dataframe for easier cleaning.
gbif_df = pd.DataFrame(new).stack().apply(pd.Series)

# %%
gbif_df.head(10)
# Out:
#     occurrenceStatus           species    year  month   day       country  \
# 0 0          PRESENT  Orycteropus afer  2014.0    9.0  30.0         Kenya
#   1          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   2          PRESENT  Orycteropus afer     NaN    NaN   NaN       Germany
#   3          PRESENT  Orycteropus afer     NaN    NaN   NaN  South Africa
#   4          PRESENT  Orycteropus afer  2015.0    4.0   8.0         Niger
#   5          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   6          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   7          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   8          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   9          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#
#                       locality occurrenceRemarks
# 0 0  Marsabit Forest Ecosystem               NaN
#   1                        NaN               NaN
#   2                        NaN               NaN
#   3                        NaN               NaN
#   4                Say, Parc W               NaN
#   5                        NaN               NaN
#   6                        NaN               NaN
#   7                        NaN               NaN
#   8                        NaN               NaN
#   9                        NaN               NaN

# %%
gbif_df.shape
# Out:
# (7420, 8)

# %%
# I wanted to investigate how many NaN values are in each column to see if there are any unnecessary variables present. I want 
# to keep all the observations, even if they have no information other than the species name because the number of observations
# was my original goal to extract from this dataset. occurrenceRemarks is the only column that I feel is unnecessary since almost
# all the rows have no value. So, I will remove that column.
gbif_df.isna().sum()
# Out:
# occurrenceStatus        0
# species               118
# year                 3216
# month                3525
# day                  3636
# country              2452
# locality             3436
# occurrenceRemarks    6731
# dtype: int64

# %%
gbif_df = gbif_df.drop('occurrenceRemarks', axis=1)

# %%
gbif_df.head(10)
# Out:
#     occurrenceStatus           species    year  month   day       country  \
# 0 0          PRESENT  Orycteropus afer  2014.0    9.0  30.0         Kenya
#   1          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   2          PRESENT  Orycteropus afer     NaN    NaN   NaN       Germany
#   3          PRESENT  Orycteropus afer     NaN    NaN   NaN  South Africa
#   4          PRESENT  Orycteropus afer  2015.0    4.0   8.0         Niger
#   5          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   6          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   7          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   8          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#   9          PRESENT  Orycteropus afer     NaN    NaN   NaN           NaN
#
#                       locality
# 0 0  Marsabit Forest Ecosystem
#   1                        NaN
#   2                        NaN
#   3                        NaN
#   4                Say, Parc W
#   5                        NaN
#   6                        NaN
#   7                        NaN
#   8                        NaN
#   9                        NaN

# %%
# I want to rearrange the columns so that the location information columns are next to each other.
gbif_df = gbif_df[['occurrenceStatus', 'species', 'country', 'locality', 'year', 'month', 'day']]

# %%
gbif_df.head()
# Out:
#     occurrenceStatus           species       country  \
# 0 0          PRESENT  Orycteropus afer         Kenya
#   1          PRESENT  Orycteropus afer           NaN
#   2          PRESENT  Orycteropus afer       Germany
#   3          PRESENT  Orycteropus afer  South Africa
#   4          PRESENT  Orycteropus afer         Niger
#
#                       locality    year  month   day
# 0 0  Marsabit Forest Ecosystem  2014.0    9.0  30.0
#   1                        NaN     NaN    NaN   NaN
#   2                        NaN     NaN    NaN   NaN
#   3                        NaN     NaN    NaN   NaN
#   4                Say, Parc W  2015.0    4.0   8.0

# %%
# Now I want to duplicate the country information to the locality information if the locality is NaN. Locality is just the more
# specific location of the observation. If that information is not available, it would be better to have the general location
# represented there.
gbif_df.locality.fillna(gbif_df.country, inplace=True)

# %%
gbif_df.head()
# Out:
#     occurrenceStatus           species       country  \
# 0 0          PRESENT  Orycteropus afer         Kenya
#   1          PRESENT  Orycteropus afer           NaN
#   2          PRESENT  Orycteropus afer       Germany
#   3          PRESENT  Orycteropus afer  South Africa
#   4          PRESENT  Orycteropus afer         Niger
#
#                       locality    year  month   day
# 0 0  Marsabit Forest Ecosystem  2014.0    9.0  30.0
#   1                        NaN     NaN    NaN   NaN
#   2                    Germany     NaN    NaN   NaN
#   3               South Africa     NaN    NaN   NaN
#   4                Say, Parc W  2015.0    4.0   8.0

# %%
# There are also NaN values represented in the country, so I want to replace those with the locality if that is available.
gbif_df.country.fillna(gbif_df.locality, inplace = True)

# %%
gbif_df.head()
# Out:
#     occurrenceStatus           species       country  \
# 0 0          PRESENT  Orycteropus afer         Kenya
#   1          PRESENT  Orycteropus afer           NaN
#   2          PRESENT  Orycteropus afer       Germany
#   3          PRESENT  Orycteropus afer  South Africa
#   4          PRESENT  Orycteropus afer         Niger
#
#                       locality    year  month   day
# 0 0  Marsabit Forest Ecosystem  2014.0    9.0  30.0
#   1                        NaN     NaN    NaN   NaN
#   2                    Germany     NaN    NaN   NaN
#   3               South Africa     NaN    NaN   NaN
#   4                Say, Parc W  2015.0    4.0   8.0

# %%
# The rest of the location NaN values I will replace with 'Unknown'.
gbif_df.update(gbif_df[['country', 'locality']].fillna('Unknown'))

# %%
# I want to reformat the date numbers from floats to integers for easier reading. I'm not sure if I need to convert them to
# datetime format yet. First, I need to replace the NaN values in those columns to zero. Then I will convert them to integers.
gbif_df.update(gbif_df[['year', 'month', 'day']].fillna(0))

# %%
gbif_df[['year', 'month', 'day']] = gbif_df[['year', 'month', 'day']].astype(int)

# %%
gbif_df.head(670)
# Out:
#      occurrenceStatus           species       country  \
# 0  0          PRESENT  Orycteropus afer         Kenya
#    1          PRESENT  Orycteropus afer       Unknown
#    2          PRESENT  Orycteropus afer       Germany
#    3          PRESENT  Orycteropus afer  South Africa
#    4          PRESENT  Orycteropus afer         Niger
# ...               ...               ...           ...
# 33 5          PRESENT   Syncerus caffer       Unknown
#    6          PRESENT   Syncerus caffer      Botswana
#    7          PRESENT   Syncerus caffer       Liberia
#    8          PRESENT   Syncerus caffer      Botswana
#    9          PRESENT   Syncerus caffer       Unknown
#
#                        locality  year  month  day
# 0  0  Marsabit Forest Ecosystem  2014      9   30
#    1                    Unknown     0      0    0
#    2                    Germany     0      0    0
#    3               South Africa     0      0    0
#    4                Say, Parc W  2015      4    8
# ...                         ...   ...    ...  ...
# 33 5                    Unknown  1834      8    1
#    6              Khwai, Mababe     0      0    0
#    7                    Liberia     0      0    0
#    8              Khwai, Mababe     0      0    0
#    9                    Unknown     0      0    0
#
# [670 rows x 7 columns]

# %%
# There are apparently 93 instances of NaN values in the species column. Since the whole point of pulling this data is to match
# information to the species, that is a problem. But I'm not entirely sure why those are NaN. So, I'm going to find the rows to
# see if I can figure out why they're NaN.
gbif_df['species'].isnull().sum()
# Out:
# 118

# %%
gbif_df[gbif_df['species'].isnull()]
# Out:
#        occurrenceStatus species             country            locality  year  \
# 1   10          PRESENT     NaN                 N/A                 N/A     0
# 6   4           PRESENT     NaN    CRANDON PARK ZOO    CRANDON PARK ZOO  1977
#     14          PRESENT     NaN                 N/A                 N/A  1976
# 10  6           PRESENT     NaN             Unknown             Unknown  1735
#     12          PRESENT     NaN             NO DATA             NO DATA  1968
# ...                 ...     ...                 ...                 ...   ...
# 359 4           PRESENT     NaN                 N/A                 N/A  1967
# 361 6           PRESENT     NaN             No data             No data  1965
#     7           PRESENT     NaN                 N/A                 N/A  1983
# 370 6           PRESENT     NaN             NO DATA             NO DATA  1980
#     15          PRESENT     NaN  CONFISCATED BY FWS  CONFISCATED BY FWS  2012
#
#         month  day
# 1   10      0    0
# 6   4      11   25
#     14      3   31
# 10  6       0    0
#     12     11   18
# ...       ...  ...
# 359 4      10   22
# 361 6       4    1
#     7       4    4
# 370 6      12   18
#     15     11   20
#
# [118 rows x 7 columns]

# %%
# The numbers on the far left indicate the list in the list of lists that was pulled from the API. I can use that to identify 
# which animal is represented by the observation. This summary also shows that there are some other variances in the way that 
# information was input into some of the columns (such as using 'N/A' or 'no specific locality' instead of leaving the information
# blank). I'm just going to drop the rows with the species NaN values since it would be a pretty big assumption to just put the 
# species in based on the list it was pulled from. Although the odds are high that it is from the same species, it also could be
# instances of misidentified species.
gbif_df = gbif_df[gbif_df['species'].notna()]

# %%
gbif_df['species'].isnull().sum() # Success
# Out:
# 0

# %%
gbif_df.shape
# Out:
# (7302, 7)

# %%
# I'm going to replace the potential 'N/A' values. I'm not sure how many other variations of 'N/A' might be present in the data.
# I might just have to deal with them as they arise. However, for the ultimate analysis, I think I'm going to end up not using
# the locality/country data anyway, and those seem to be the main inconsistencies.
gbif_df = gbif_df.replace('N/A', 'Unknown')

# %%
#Store clean dataframe as CSV
gbif_df.to_csv('dsc540_gbif.csv', index=False)
